# %%
import pandas as pd
import geopandas as gpd

# %%
rotten_tomatoes = pd.read_csv('./data/rotten_tomatoes_movies.csv')

# %%
rotten_tomatoes
# Out:
#                                    rotten_tomatoes_link  \
# 0                                            /m/0814255
# 1                                            /m/0878835
# 2                                                 /m/10
# 3                               /m/1000013-12_angry_men
# 4                /m/1000079-20000_leagues_under_the_sea
# 5                                           /m/10000_bc
# 6                                   /m/1000121-39_steps
# 7                                /m/1000123-310_to_yuma
# 8                                    /m/10002008-charly
# 9                            /m/1000204-abraham_lincoln
# 10                               /m/10002114-dark_water
# 11                                   /m/1000224-accused
# 12                                /m/10002516-lost_city
# 13                           /m/10002519-breaking_point
# 14                                 /m/1000253-adams_rib
# 15                   /m/10002635-bridge_of_san_luis_rey
# ...

# %%
rotten_tomatoes.drop(['rotten_tomatoes_link'], axis=1)
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# 5                                            10,000 B.C.
# 6                                           The 39 Steps
# 7                                           3:10 to Yuma
# 8                              Charly (A Heartbeat Away)
# 9                                        Abraham Lincoln
# 10                                            Dark Water
# 11                                           The Accused
# 12                                         The Lost City
# 13                                    The Breaking Point
# 14                                            Adam's Rib
# ...

# %%
rotten2 = rotten_tomatoes.drop(['critics_consensus','poster_image_url','writers','cast','studio_name','audience_status','audience_rating','audience_count','audience_top_critics_count','audience_fresh_critics_count','audience_rotten_critics_count'], axis=1)

# %%
rotten_tomatoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16638 entries, 0 to 16637
# Data columns (total 23 columns):
# rotten_tomatoes_link             16638 non-null object
# movie_title                      16638 non-null object
# movie_info                       16614 non-null object
# critics_consensus                8309 non-null object
# poster_image_url                 16638 non-null object
# rating                           16638 non-null object
# genre                            16621 non-null object
# directors                        16524 non-null object
# writers                          15289 non-null object
# cast                             16354 non-null object
# in_theaters_date                 15823 non-null object
# on_streaming_date                16636 non-null object
# runtime_in_minutes               16483 non-null float64
# studio_name                      16222 non-null object
# tomatometer_status               16638 non-null object
# ...

# %%
rotten
# Out:
#                                    rotten_tomatoes_link  \
# 0                                            /m/0814255
# 1                                            /m/0878835
# 2                                                 /m/10
# 3                               /m/1000013-12_angry_men
# 4                /m/1000079-20000_leagues_under_the_sea
# 5                                           /m/10000_bc
# 6                                   /m/1000121-39_steps
# 7                                /m/1000123-310_to_yuma
# 8                                    /m/10002008-charly
# 9                            /m/1000204-abraham_lincoln
# 10                               /m/10002114-dark_water
# 11                                   /m/1000224-accused
# 12                                /m/10002516-lost_city
# 13                           /m/10002519-breaking_point
# 14                                 /m/1000253-adams_rib
# 15                   /m/10002635-bridge_of_san_luis_rey
# ...

# %%
rotten2 = rotten2.drop(['on_streaming_date','runtime_in_minutes','rotten_tomatoes_link'], axis=1)

# %%
rotten3 = rotten2[rotten2['tomatometer_count'] >= 50]

# %%
rotten3
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 3                        12 Angry Men (Twelve Angry Men)
# 5                                            10,000 B.C.
# 12                                         The Lost City
# 17                                              Criminal
# 19                                             Deep Blue
# 25                                      Tristan & Isolde
# 28                                        Running Scared
# 30                                           Ultraviolet
# 32     Arthur and the Invisibles (Arthur and the Mini...
# 37                                           The Matador
# 40                                           Saint Ralph
# 41                                            The Baxter
# 42                                          Oliver Twist
# ...

# %%
rotten3.sort_values(by ='tomatometer_rating', ascending = False)
# Out:
#                                              movie_title  \
# 8747                               The Last Picture Show
# 15414                                          Toy Story
# 10899                                       Paddington 2
# 5094                                Deliver Us from Evil
# 11144                             The Philadelphia Story
# 14895                              The Square (Al Midan)
# 2284                                         Afghan Star
# 15415                                        Toy Story 2
# 1926              The 400 Blows (Les Quatre cents coups)
# 15950                                     Wake in Fright
# 12588                                Singin' in the Rain
# 13340                                The Sweet Hereafter
# 8825                                      Leave No Trace
# 8564                                Knock Down the House
# 996            Three Colors: Red (Trois couleurs: Rouge)
# ...

# %%
rotten3 = rotten3[rotten3['tomatometer_rating'] > 89]

# %%
rotten3.tail()
# Out:
#                        movie_title  \
# 16582  Your Name. (Kimi No Na Wa.)
# 16612             Zero Dark Thirty
# 16613                    Zero Days
# 16626                   Zombieland
# 16634                     Zootopia
#
#                                               movie_info rating  \
# 16582  From director Makoto Shinkai, the innovative m...     PG
# 16612  For a decade, an elite team of intelligence an...      R
# 16613  A documentary thriller about the world of cybe...  PG-13
# 16626  A cowardly shut-in named Columbus (Jesse Eisen...      R
# 16634  The modern mammal metropolis of Zootopia is a ...     PG
#
#                                        genre  \
# 16582              Animation, Drama, Romance
# 16612                                  Drama
# 16613                            Documentary
# 16626                         Comedy, Horror
# 16634  Action & Adventure, Animation, Comedy
#
#                                   directors in_theaters_date  \
# ...

# %%
rotten3.sort_values(by ='tomatometer_rating', ascending = False)
# Out:
#                                              movie_title  \
# 3                        12 Angry Men (Twelve Angry Men)
# 672                                          Rear Window
# 8747                               The Last Picture Show
# 545                                                Laura
# 8825                                      Leave No Trace
# 569                                                    M
# 575                                   The Maltese Falcon
# 13340                                The Sweet Hereafter
# 8564                                Knock Down the House
# 12338               Seven Samurai (Shichinin no Samurai)
# 11193                                          Pinocchio
# 12371                           Seymour: An Introduction
# 12482                                           Shirkers
# 14895                              The Square (Al Midan)
# 6577                  GETT: The Trial of Viviane Amsalem
# ...

# %%
rotten4 = rotten3[rotten3['tomatometer_rating'] > 95]

# %%
rotten4.sort_values(by ='tomatometer_rating', ascending = False)
# Out:
#                                              movie_title  \
# 3                        12 Angry Men (Twelve Angry Men)
# 996            Three Colors: Red (Trois couleurs: Rouge)
# 8747                               The Last Picture Show
# 15415                                        Toy Story 2
# 12371                           Seymour: An Introduction
# 15414                                          Toy Story
# 13340                                The Sweet Hereafter
# 4389                                        Citizen Kane
# 13444                                            Tampopo
# 6577                  GETT: The Trial of Viviane Amsalem
# 13474                              Taxi to the Dark Side
# 2284                                         Afghan Star
# 8564                                Knock Down the House
# 13527                                     The Terminator
# 12338               Seven Samurai (Shichinin no Samurai)
# ...

# %%
rotten4.to_csv('rotten_tomatoes.csv')
